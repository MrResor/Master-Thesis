# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
points = pd.read_csv('xqg237.points')
points = points.values

# %%
a = plt.scatter(points[:, 1], points[:, 2])

# %%
path = '61->67->66->50->49->41->40->48->47->46->56->60->58->55->57->59->64->54->35->36->37->38->39->33->32->31->30->25->28->23->22->17->15->14->13->7->0->8->4->5->1->9->10->11->6->2->3->12->27->24->21->16->20->19->18->26->29->34->42->43->51->52->63->62->68->69->70->71->53->44->65->45->72->77->111->126->125->133->142->143->179->178->187->201->212->211->223->235->236->234->233->222->210->200->199->220->232->231->230->229->228->227->226->224->221->213->202->197->189->181->180->188->190->203->225->204->205->214->206->207->215->218->216->219->217->208->209->198->186->177->170->141->132->124->113->112->123->131->130->122->121->139->140->162->163->161->160->159->158->157->156->155->138->167->168->169->185->196->195->194->193->192->191->184->183->182->174->175->176->154->153->152->137->151->166->165->150->149->148->147->146->145->164->173->172->171->144->135->136->134->129->128->127->117->118->119->120->107->108->109->110->101->76->85->84->99->98->83->75->74->82->81->80->89->93->90->94->91->97->106->105->104->102->96->103->114->116->115->88->87->100->95->92->86->73->78->79'
path = list(map(int, path.split("->")))
path
# Out:
# [61,
#  67,
#  66,
#  50,
#  49,
#  41,
#  40,
#  48,
#  47,
#  46,
#  56,
#  60,
#  58,
#  55,
#  57,
#  59,
#  64,
#  54,
#  35,
#  36,
#  37,
#  38,
#  39,
#  33,
#  32,
#  31,
#  30,
#  25,
#  28,
#  23,
#  22,
#  17,
#  15,
#  14,
#  13,
#  7,
#  0,
#  8,
#  4,
#  5,
#  1,
#  9,
#  10,
#  11,
#  6,
#  2,
#  3,
#  12,
#  27,
#  24,
#  21,
#  16,
#  20,
#  19,
#  18,
#  26,
#  29,
#  34,
#  42,
#  43,
#  51,
#  52,
#  63,
#  62,
#  68,
#  69,
#  70,
#  71,
#  53,
#  44,
#  65,
#  45,
#  72,
#  77,
#  111,
#  126,
#  125,
#  133,
#  142,
#  143,
#  179,
#  178,
#  187,
#  201,
#  212,
#  211,
#  223,
#  235,
#  236,
#  234,
#  233,
#  222,
#  210,
#  200,
#  199,
#  220,
#  232,
#  231,
#  230,
#  229,
#  228,
#  227,
#  226,
#  224,
#  221,
#  213,
#  202,
#  197,
#  189,
#  181,
#  180,
#  188,
#  190,
#  203,
#  225,
#  204,
#  205,
#  214,
#  206,
#  207,
#  215,
#  218,
#  216,
#  219,
#  217,
#  208,
#  209,
#  198,
#  186,
#  177,
#  170,
#  141,
#  132,
#  124,
#  113,
# ...

# %%
plt.scatter(points[:, 1], points[:, 2])
for (p1, p2) in zip(path, np.roll(path, -1)):
    plt.plot([points[p1, 1], points[p2, 1]], [points[p1, 2], points[p2, 2]], '-r')
plt.show()

# %%
data = pd.read_csv('xqg237.csv').values
present = np.zeros((2 * data.shape[0], data.shape[1]))
for i, d in enumerate(data):
    present[2*i] = d
    present[2*i + 1] = [d[1], d[0], d[2]]
present = pd.DataFrame(present)
present.columns = ['From', 'To', 'Distance']
print(present.to_string(index=False))
# Out:
#  From    To  Distance
#   1.0   2.0      18.0
#   2.0   1.0      18.0
#   1.0   3.0      36.0
#   3.0   1.0      36.0
#   1.0   4.0      45.0
#   4.0   1.0      45.0
#   1.0   5.0       6.0
#   5.0   1.0       6.0
#   1.0   6.0      13.0
#   6.0   1.0      13.0
#   1.0   7.0      29.0
#   7.0   1.0      29.0
#   1.0   8.0       5.0
#   8.0   1.0       5.0
#   1.0   9.0       6.0
#   9.0   1.0       6.0
#   1.0  10.0      19.0
#  10.0   1.0      19.0
#   1.0  11.0      22.0
#  11.0   1.0      22.0
#   1.0  12.0      25.0
#  12.0   1.0      25.0
#   1.0  13.0      49.0
#  13.0   1.0      49.0
#   1.0  14.0       9.0
#  14.0   1.0       9.0
#   1.0  15.0      10.0
#  15.0   1.0      10.0
#   1.0  16.0      11.0
#  16.0   1.0      11.0
#   1.0  17.0      29.0
#  17.0   1.0      29.0
#   1.0  18.0      12.0
#  18.0   1.0      12.0
#   1.0  19.0      11.0
#  19.0   1.0      11.0
#   1.0  20.0      19.0
#  20.0   1.0      19.0
#   1.0  21.0      22.0
#  21.0   1.0      22.0
# ...

# %%
present = present.values
present = present[present[:, -1].argsort(), :]
present = pd.DataFrame(present)
present.columns = ['From', 'To', 'Distance']
print(present.to_string(index=False))
# Out:
#  From    To  Distance
#  15.0  16.0       1.0
#  59.0  57.0       1.0
#  57.0  59.0       1.0
#  58.0  56.0       1.0
#  56.0  58.0       1.0
# 161.0 162.0       1.0
# 162.0 161.0       1.0
# 163.0 164.0       1.0
# 164.0 163.0       1.0
#  34.0  33.0       1.0
#  33.0  34.0       1.0
#  33.0  32.0       1.0
#  32.0  33.0       1.0
# 168.0 169.0       1.0
# 169.0 168.0       1.0
# 169.0 170.0       1.0
#  58.0  60.0       1.0
#  60.0  58.0       1.0
# 135.0 130.0       1.0
# 130.0 135.0       1.0
#  89.0  88.0       1.0
#  90.0  94.0       1.0
#  94.0  90.0       1.0
#  93.0  96.0       1.0
#  96.0  93.0       1.0
# 219.0 216.0       1.0
# 216.0 219.0       1.0
# 170.0 169.0       1.0
# 116.0 117.0       1.0
#  16.0  15.0       1.0
# 128.0 129.0       1.0
# 129.0 128.0       1.0
# 129.0 130.0       1.0
# 130.0 129.0       1.0
#  61.0  59.0       1.0
#  59.0  61.0       1.0
# 117.0 116.0       1.0
# 181.0 182.0       1.0
#  88.0  89.0       1.0
# 197.0 196.0       1.0
# ...
